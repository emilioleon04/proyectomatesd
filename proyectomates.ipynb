# %%
pip install networkx

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 500
import networkx as nx

# %%
G = nx.Graph()
nodos = ["Anakin Skywalker/Darth Vader", "Obi-Wan Kenobi", "C-3PO", "Chewbacca", "Conde Dooku", "General Grievous", "Han Solo", "Jabba el Hutt", "Jar Jar Binks", "Ki-Adi Mundi"
        , "Luke Skywalker", "Mace Windu", "Palpatine", "Leia Organa", "Qui-Gon Jinn", "R2-D2", "Padme Amidala", "Almirante Ackbar", "Darth Maul", "Jango Fett", "Greedo", "Boba Fett"
        , "Moff Gideon", "Mon Mothma", "Cody", "Plo Koon", "Watto", "Senado Galactico", "Consejo Jedi", "Panaka", "Jefe Nass", "Mas Amedda", "Kit Fisto", "Yoda"
        , "Nute Gunray", "Jamillia", "Dexter Jettster", "Owen Lars", "Jocasta Nu", "Bail Prestor Organa", "Aayla Secura", "Lama Su", "Orn Free Taa", "Luminara Unduli", "Depa Billaba", "Hela Brandes"
        , "Onaconda Farr", "Aks Moe", "Rugor Nass", "Even Piell"]
G.add_nodes_from(nodos)

# %%
G.add_edges_from([("Anakin Skywalker/Darth Vader", "Obi-Wan Kenobi"),("Anakin Skywalker/Darth Vader", "Luke Skywalker"),("Anakin Skywalker/Darth Vader", "Senado Galactico"),("Anakin Skywalker/Darth Vader", "Darth Maul"), ("Anakin Skywalker/Darth Vader", "Owen Lars"),
                 ("Anakin Skywalker/Darth Vader", "Padme Amidala"),("Anakin Skywalker/Darth Vader", "Jar Jar Binks"),("Anakin Skywalker/Darth Vader", "Watto"),("Anakin Skywalker/Darth Vader", "Palpatine"),("Anakin Skywalker/Darth Vader", "Han Solo"), ("Anakin Skywalker/Darth Vader", "Yoda"),
                 ("Anakin Skywalker/Darth Vader", "C-3PO"),("Anakin Skywalker/Darth Vader", "R2-D2"),("Anakin Skywalker/Darth Vader", "Qui-Gon Jinn"),("Anakin Skywalker/Darth Vader", "Leia Organa"),("Anakin Skywalker/Darth Vader", "Jango Fett"),("Anakin Skywalker/Darth Vader", "General Grievous"),
                 ("Anakin Skywalker/Darth Vader", "Conde Dooku"),("Anakin Skywalker/Darth Vader", "Consejo Jedi"), ("Anakin Skywalker/Darth Vader", "Moff Gideon"), ("Anakin Skywalker/Darth Vader", "Boba Fett"), ("Anakin Skywalker/Darth Vader", "Mace Windu"),("Anakin Skywalker/Darth Vader", "Owen Lars")])

# %%
G.add_edges_from([("Padme Amidala", "Obi-Wan Kenobi"), ("Padme Amidala", "R2-D2"), ("Padme Amidala", "C-3PO"), ("Padme Amidala", "Qui-Gon Jinn"), ("Padme Amidala", "Senado Galactico"),("Padme Amidala", "Hela Brandes"),("Padme Amidala", "Rugor Nass"),
                 ("Padme Amidala", "Jamillia"),("Padme Amidala", "Jefe Nass"),("Padme Amidala", "Bail Prestor Organa"),("Padme Amidala", "Palpatine"),("Padme Amidala", "Mon Mothma"),("Padme Amidala", "Panaka"),("Padme Amidala", "Onaconda Farr"),])

# %%
G.add_edges_from([("Luke Skywalker", "Obi-Wan Kenobi"), ("Luke Skywalker", "Leia Organa"), ("Luke Skywalker", "Chewbacca"), ("Luke Skywalker", "Han Solo"), ("Luke Skywalker", "Jabba el Hutt"),
                 ("Luke Skywalker", "Boba Fett"), ("Luke Skywalker", "R2-D2"), ("Luke Skywalker", "C-3PO"), ("Luke Skywalker", "Anakin Skywalker/Darth Vader"), ("Luke Skywalker", "Palpatine"),
                 ("Luke Skywalker", "Yoda"), ("Luke Skywalker", "Owen Lars"),])

# %%
G.add_edges_from([("Obi-Wan Kenobi", "Plo Koon"), ("Obi-Wan Kenobi", "Palpatine"), ("Obi-Wan Kenobi", "Aayla Secura"), ("Obi-Wan Kenobi", "Jocasta Nu"),("Obi-Wan Kenobi", "R2-D2"),("Obi-Wan Kenobi", "Mas Amedda"),
                 ("Obi-Wan Kenobi", "Plo Koon"), ("Obi-Wan Kenobi", "Lama Su"), ("Obi-Wan Kenobi", "Consejo Jedi"), ("Obi-Wan Kenobi", "Cody"), ("Obi-Wan Kenobi", "C-3PO"),("Obi-Wan Kenobi", "Dexter Jettster"),("Obi-Wan Kenobi", "Depa Billaba"),
                 ("Obi-Wan Kenobi", "Kit Fisto"), ("Obi-Wan Kenobi", "Yoda"),("Obi-Wan Kenobi", "Lama Su"), ("Obi-Wan Kenobi", "Luminara Unduli"),("Obi-Wan Kenobi", "Ki-Adi Mundi"),("Obi-Wan Kenobi", "Owen Lars"),("Obi-Wan Kenobi", "Even Piell"),])

# %%
G.add_edges_from([("Leia Organa", "Han Solo"), ("Leia Organa", "R2-D2"), ("Leia Organa", "Chewbacca"),("Leia Organa", "C-3PO"), ("Leia Organa", "Jabba el Hutt"), ("Leia Organa", "Anakin Skywalker/Darth Vader"),
                 ("Leia Organa", "Almirante Ackbar"), ("Leia Organa", "Bail Prestor Organa"), ("Leia Organa", "Mon Mothma"),])

# %%
G.add_edges_from([("Palpatine", "Nute Gunray"), ("Palpatine", "Yoda"), ("Palpatine", "Cody"), ("Palpatine", "Mace Windu"), ("Palpatine", "Darth Maul"), 
                 ("Palpatine", "Orn Free Taa"), ("Palpatine", "R2-D2"), ("Palpatine", "Conde Dooku"),])

# %%
G.add_edges_from([("Han Solo", "Chewbacca"), ("Han Solo", "Greedo"), ("Han Solo", "Jabba el Hutt"),])

# %%
G.add_edges_from([("Senado Galactico", "Onaconda Farr"), ("Senado Galactico", "Aks Moe"), ("Han Solo", "Jabba el Hutt"),])

# %%
edge_labels = nx.get_edge_attributes(G, 'label')
edge_colors = [0 if label == 'Amistad' else 1 for label in edge_labels.values()] 

degree_centrality = nx.degree_centrality(G)
node_sizes = [s * 2000 for s in degree_centrality.values()]

pos = nx.spring_layout(G, k=1)
nx.draw(G, pos=pos, with_labels=True, node_color='#9370DB', node_size=node_sizes, edge_cmap=plt.cm.Blues, edge_color='lightblue', font_size=4)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=3,)
plt.show()

# %%
G.number_of_nodes()
# Out:
# 50

# %%
list(G.nodes())
# Out:
# ['Anakin Skywalker/Darth Vader',
#  'Obi-Wan Kenobi',
#  'C-3PO',
#  'Chewbacca',
#  'Conde Dooku',
#  'General Grievous',
#  'Han Solo',
#  'Jabba el Hutt',
#  'Jar Jar Binks',
#  'Ki-Adi Mundi',
#  'Luke Skywalker',
#  'Mace Windu',
#  'Palpatine',
#  'Leia Organa',
#  'Qui-Gon Jinn',
#  'R2-D2',
#  'Padme Amidala',
#  'Almirante Ackbar',
#  'Darth Maul',
#  'Jango Fett',
#  'Greedo',
#  'Boba Fett',
#  'Moff Gideon',
#  'Mon Mothma',
#  'Cody',
#  'Plo Koon',
#  'Watto',
#  'Senado Galactico',
#  'Consejo Jedi',
#  'Panaka',
#  'Jefe Nass',
#  'Mas Amedda',
#  'Kit Fisto',
#  'Yoda',
#  'Nute Gunray',
#  'Jamillia',
#  'Dexter Jettster',
#  'Owen Lars',
#  'Jocasta Nu',
#  'Bail Prestor Organa',
#  'Aayla Secura',
#  'Lama Su',
#  'Orn Free Taa',
#  'Luminara Unduli',
#  'Depa Billaba',
#  'Hela Brandes',
#  'Onaconda Farr',
#  'Aks Moe',
#  'Rugor Nass',
#  'Even Piell']

# %%
G.number_of_edges()
# Out:
# 86

# %%
list(G.edges())
# Out:
# [('Anakin Skywalker/Darth Vader', 'Obi-Wan Kenobi'),
#  ('Anakin Skywalker/Darth Vader', 'Luke Skywalker'),
#  ('Anakin Skywalker/Darth Vader', 'Senado Galactico'),
#  ('Anakin Skywalker/Darth Vader', 'Darth Maul'),
#  ('Anakin Skywalker/Darth Vader', 'Owen Lars'),
#  ('Anakin Skywalker/Darth Vader', 'Padme Amidala'),
#  ('Anakin Skywalker/Darth Vader', 'Jar Jar Binks'),
#  ('Anakin Skywalker/Darth Vader', 'Watto'),
#  ('Anakin Skywalker/Darth Vader', 'Palpatine'),
#  ('Anakin Skywalker/Darth Vader', 'Han Solo'),
#  ('Anakin Skywalker/Darth Vader', 'Yoda'),
#  ('Anakin Skywalker/Darth Vader', 'C-3PO'),
#  ('Anakin Skywalker/Darth Vader', 'R2-D2'),
#  ('Anakin Skywalker/Darth Vader', 'Qui-Gon Jinn'),
#  ('Anakin Skywalker/Darth Vader', 'Leia Organa'),
#  ('Anakin Skywalker/Darth Vader', 'Jango Fett'),
#  ('Anakin Skywalker/Darth Vader', 'General Grievous'),
#  ('Anakin Skywalker/Darth Vader', 'Conde Dooku'),
#  ('Anakin Skywalker/Darth Vader', 'Consejo Jedi'),
# ...

# %%
list(G.adj["Anakin Skywalker/Darth Vader"])
# Out:
# ['Obi-Wan Kenobi',
#  'Luke Skywalker',
#  'Senado Galactico',
#  'Darth Maul',
#  'Owen Lars',
#  'Padme Amidala',
#  'Jar Jar Binks',
#  'Watto',
#  'Palpatine',
#  'Han Solo',
#  'Yoda',
#  'C-3PO',
#  'R2-D2',
#  'Qui-Gon Jinn',
#  'Leia Organa',
#  'Jango Fett',
#  'General Grievous',
#  'Conde Dooku',
#  'Consejo Jedi',
#  'Moff Gideon',
#  'Boba Fett',
#  'Mace Windu']

# %%
list(G.neighbors("Anakin Skywalker/Darth Vader"))
# Out:
# ['Obi-Wan Kenobi',
#  'Luke Skywalker',
#  'Senado Galactico',
#  'Darth Maul',
#  'Owen Lars',
#  'Padme Amidala',
#  'Jar Jar Binks',
#  'Watto',
#  'Palpatine',
#  'Han Solo',
#  'Yoda',
#  'C-3PO',
#  'R2-D2',
#  'Qui-Gon Jinn',
#  'Leia Organa',
#  'Jango Fett',
#  'General Grievous',
#  'Conde Dooku',
#  'Consejo Jedi',
#  'Moff Gideon',
#  'Boba Fett',
#  'Mace Windu']

# %%
G.degree["Anakin Skywalker/Darth Vader"]
# Out:
# 22

# %%
list(G.degree())
# Out:
# [('Anakin Skywalker/Darth Vader', 22),
#  ('Obi-Wan Kenobi', 21),
#  ('C-3PO', 5),
#  ('Chewbacca', 3),
#  ('Conde Dooku', 2),
#  ('General Grievous', 1),
#  ('Han Solo', 6),
#  ('Jabba el Hutt', 3),
#  ('Jar Jar Binks', 1),
#  ('Ki-Adi Mundi', 1),
#  ('Luke Skywalker', 12),
#  ('Mace Windu', 2),
#  ('Palpatine', 12),
#  ('Leia Organa', 10),
#  ('Qui-Gon Jinn', 2),
#  ('R2-D2', 6),
#  ('Padme Amidala', 15),
#  ('Almirante Ackbar', 1),
#  ('Darth Maul', 2),
#  ('Jango Fett', 1),
#  ('Greedo', 1),
#  ('Boba Fett', 2),
#  ('Moff Gideon', 1),
#  ('Mon Mothma', 2),
#  ('Cody', 2),
#  ('Plo Koon', 1),
#  ('Watto', 1),
#  ('Senado Galactico', 4),
#  ('Consejo Jedi', 2),
#  ('Panaka', 1),
#  ('Jefe Nass', 1),
#  ('Mas Amedda', 1),
#  ('Kit Fisto', 1),
#  ('Yoda', 4),
#  ('Nute Gunray', 1),
#  ('Jamillia', 1),
#  ('Dexter Jettster', 1),
#  ('Owen Lars', 3),
#  ('Jocasta Nu', 1),
#  ('Bail Prestor Organa', 2),
#  ('Aayla Secura', 1),
#  ('Lama Su', 1),
#  ('Orn Free Taa', 1),
# ...

# %%
nx.eccentricity(G)
# Out:
# {'Anakin Skywalker/Darth Vader': 2,
#  'Obi-Wan Kenobi': 3,
#  'C-3PO': 3,
#  'Chewbacca': 4,
#  'Conde Dooku': 3,
#  'General Grievous': 3,
#  'Han Solo': 3,
#  'Jabba el Hutt': 4,
#  'Jar Jar Binks': 3,
#  'Ki-Adi Mundi': 4,
#  'Luke Skywalker': 3,
#  'Mace Windu': 3,
#  'Palpatine': 3,
#  'Leia Organa': 3,
#  'Qui-Gon Jinn': 3,
#  'R2-D2': 3,
#  'Padme Amidala': 3,
#  'Almirante Ackbar': 4,
#  'Darth Maul': 3,
#  'Jango Fett': 3,
#  'Greedo': 4,
#  'Boba Fett': 3,
#  'Moff Gideon': 3,
#  'Mon Mothma': 3,
#  'Cody': 4,
#  'Plo Koon': 4,
#  'Watto': 3,
#  'Senado Galactico': 3,
#  'Consejo Jedi': 3,
#  'Panaka': 4,
#  'Jefe Nass': 4,
#  'Mas Amedda': 4,
#  'Kit Fisto': 4,
#  'Yoda': 3,
#  'Nute Gunray': 4,
#  'Jamillia': 4,
#  'Dexter Jettster': 4,
#  'Owen Lars': 3,
#  'Jocasta Nu': 4,
#  'Bail Prestor Organa': 3,
#  'Aayla Secura': 4,
#  'Lama Su': 4,
#  'Orn Free Taa': 4,
#  'Luminara Unduli': 4,
#  'Depa Billaba': 4,
#  'Hela Brandes': 4,
#  'Onaconda Farr': 4,
#  'Aks Moe': 4,
# ...

# %%
nx.radius(G)
# Out:
# 2

# %%
nx.diameter(G)
# Out:
# 4

# %%
center_nodes = [node for node in G.nodes() if nx.eccentricity(G, node) == nx.radius(G)]
print(center_nodes)
# Out:
# ['Anakin Skywalker/Darth Vader']

# %%
periphery_nodes = [node for node in G.nodes() if nx.eccentricity(G, node) == nx.diameter(G)]
print(periphery_nodes)
# Out:
# ['Chewbacca', 'Jabba el Hutt', 'Ki-Adi Mundi', 'Almirante Ackbar', 'Greedo', 'Cody', 'Plo Koon', 'Panaka', 'Jefe Nass', 'Mas Amedda', 'Kit Fisto', 'Nute Gunray', 'Jamillia', 'Dexter Jettster', 'Jocasta Nu', 'Aayla Secura', 'Lama Su', 'Orn Free Taa', 'Luminara Unduli', 'Depa Billaba', 'Hela Brandes', 'Onaconda Farr', 'Aks Moe', 'Rugor Nass', 'Even Piell']
